# %% [markdown]
# # Load the Liberaries

# %%
import numpy as np
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# # Reading Dataset

# %%
dframe=pd.read_csv("C:/Projects/Google-Stock-Price-Prediction-ML/Data set/GOOG.csv")

# %%
dframe.head()
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
dframe.tail()
# Out:
#      symbol                       date    close      high        low     open  \
# 1253   GOOG  2021-06-07 00:00:00+00:00  2466.09  2468.000  2441.0725  2451.32
# 1254   GOOG  2021-06-08 00:00:00+00:00  2482.85  2494.495  2468.2400  2479.90
# 1255   GOOG  2021-06-09 00:00:00+00:00  2491.40  2505.000  2487.3300  2499.50
# 1256   GOOG  2021-06-10 00:00:00+00:00  2521.60  2523.260  2494.0000  2494.01
# 1257   GOOG  2021-06-11 00:00:00+00:00  2513.93  2526.990  2498.2900  2524.92
#
#        volume  adjClose   adjHigh     adjLow  adjOpen  adjVolume  divCash  \
# 1253  1192453   2466.09  2468.000  2441.0725  2451.32    1192453      0.0
# 1254  1253253   2482.85  2494.495  2468.2400  2479.90    1253253      0.0
# 1255  1006337   2491.40  2505.000  2487.3300  2499.50    1006337      0.0
# 1256  1561733   2521.60  2523.260  2494.0000  2494.01    1561733      0.0
# 1257  1262309   2513.93  2526.990  2498.2900  2524.92    1262309      0.0
#
#       splitFactor
# 1253          1.0
# 1254          1.0
# 1255          1.0
# 1256          1.0
# 1257          1.0

# %% [markdown]
# # Gather Info and Structure

# %%
dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %% [markdown]
# # Descriptive Statistics: Generate summary statistics for numerical columns.

# %%
dframe.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
dframe.isnull().sum() # return those columns that are null
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
dframe.drop('divCash',axis=1)# Dropping this as it is completely null
# Out:
#      symbol                       date    close      high        low     open  \
# 0      GOOG  2016-06-14 00:00:00+00:00   718.27   722.470   713.1200   716.48
# 1      GOOG  2016-06-15 00:00:00+00:00   718.92   722.980   717.3100   719.00
# 2      GOOG  2016-06-16 00:00:00+00:00   710.36   716.650   703.2600   714.91
# 3      GOOG  2016-06-17 00:00:00+00:00   691.72   708.820   688.4515   708.65
# 4      GOOG  2016-06-20 00:00:00+00:00   693.71   702.480   693.4100   698.77
# ...     ...                        ...      ...       ...        ...      ...
# 1253   GOOG  2021-06-07 00:00:00+00:00  2466.09  2468.000  2441.0725  2451.32
# 1254   GOOG  2021-06-08 00:00:00+00:00  2482.85  2494.495  2468.2400  2479.90
# 1255   GOOG  2021-06-09 00:00:00+00:00  2491.40  2505.000  2487.3300  2499.50
# 1256   GOOG  2021-06-10 00:00:00+00:00  2521.60  2523.260  2494.0000  2494.01
# 1257   GOOG  2021-06-11 00:00:00+00:00  2513.93  2526.990  2498.2900  2524.92
#
#        volume  adjClose   adjHigh     adjLow  adjOpen  adjVolume  splitFactor
# 0     1306065    718.27   722.470   713.1200   716.48    1306065          1.0
# 1     1214517    718.92   722.980   717.3100   719.00    1214517          1.0
# 2     1982471    710.36   716.650   703.2600   714.91    1982471          1.0
# 3     3402357    691.72   708.820   688.4515   708.65    3402357          1.0
# 4     2082538    693.71   702.480   693.4100   698.77    2082538          1.0
# ...       ...       ...       ...        ...      ...        ...          ...
# 1253  1192453   2466.09  2468.000  2441.0725  2451.32    1192453          1.0
# 1254  1253253   2482.85  2494.495  2468.2400  2479.90    1253253          1.0
# 1255  1006337   2491.40  2505.000  2487.3300  2499.50    1006337          1.0
# 1256  1561733   2521.60  2523.260  2494.0000  2494.01    1561733          1.0
# 1257  1262309   2513.93  2526.990  2498.2900  2524.92    1262309          1.0
#
# [1258 rows x 13 columns]

# %%
# Visualizing the D

# %%
# adding an index column
dframe = dframe.reset_index()
dframe['index'] = dframe['index'] + 2

# %%
dframe.head(2)
# Out:
#    index symbol                       date   close    high     low    open  \
# 0      2   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.12  716.48
# 1      3   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.31  719.00
#
#     volume  adjClose  adjHigh  adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.12   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.31   719.00    1214517      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0

# %%
training_set = dframe.iloc[:,1:2].values
print('shape is ={}'.format(training_set.shape))
print(training_set[0:5])
dframe.head()
# Out:
# shape is =(1258, 1)
# [['GOOG']
#  ['GOOG']
#  ['GOOG']
#  ['GOOG']
#  ['GOOG']]
#    index symbol                       date   close    high       low    open  \
# 0      2   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1      3   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2      4   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3      5   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4      6   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
dframe = dframe.sort_values(by='date')
dframe
# Out:
#       index symbol        date    close      high        low     open  \
# 0         2   GOOG  2016-06-14   718.27   722.470   713.1200   716.48
# 1         3   GOOG  2016-06-15   718.92   722.980   717.3100   719.00
# 2         4   GOOG  2016-06-16   710.36   716.650   703.2600   714.91
# 3         5   GOOG  2016-06-17   691.72   708.820   688.4515   708.65
# 4         6   GOOG  2016-06-20   693.71   702.480   693.4100   698.77
# ...     ...    ...         ...      ...       ...        ...      ...
# 1253   1255   GOOG  2021-06-07  2466.09  2468.000  2441.0725  2451.32
# 1254   1256   GOOG  2021-06-08  2482.85  2494.495  2468.2400  2479.90
# 1255   1257   GOOG  2021-06-09  2491.40  2505.000  2487.3300  2499.50
# 1256   1258   GOOG  2021-06-10  2521.60  2523.260  2494.0000  2494.01
# 1257   1259   GOOG  2021-06-11  2513.93  2526.990  2498.2900  2524.92
#
#        volume  adjClose   adjHigh     adjLow  adjOpen  adjVolume  divCash  \
# 0     1306065    718.27   722.470   713.1200   716.48    1306065      0.0
# 1     1214517    718.92   722.980   717.3100   719.00    1214517      0.0
# 2     1982471    710.36   716.650   703.2600   714.91    1982471      0.0
# 3     3402357    691.72   708.820   688.4515   708.65    3402357      0.0
# 4     2082538    693.71   702.480   693.4100   698.77    2082538      0.0
# ...       ...       ...       ...        ...      ...        ...      ...
# 1253  1192453   2466.09  2468.000  2441.0725  2451.32    1192453      0.0
# 1254  1253253   2482.85  2494.495  2468.2400  2479.90    1253253      0.0
# 1255  1006337   2491.40  2505.000  2487.3300  2499.50    1006337      0.0
# 1256  1561733   2521.60  2523.260  2494.0000  2494.01    1561733      0.0
# 1257  1262309   2513.93  2526.990  2498.2900  2524.92    1262309      0.0
#
#       splitFactor
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0
# ...           ...
# 1253          1.0
# 1254          1.0
# 1255          1.0
# 1256          1.0
# 1257          1.0
#
# [1258 rows x 15 columns]

# %%
# Convert the 'date' column to datetime format
dframe['date'] = pd.to_datetime(dframe['date'])

# Apply the strftime function
dframe['date'] = dframe['date'].dt.strftime('%Y-%m-%d')
dframe
# Out:
#       index symbol        date    close      high        low     open  \
# 0         2   GOOG  2016-06-14   718.27   722.470   713.1200   716.48
# 1         3   GOOG  2016-06-15   718.92   722.980   717.3100   719.00
# 2         4   GOOG  2016-06-16   710.36   716.650   703.2600   714.91
# 3         5   GOOG  2016-06-17   691.72   708.820   688.4515   708.65
# 4         6   GOOG  2016-06-20   693.71   702.480   693.4100   698.77
# ...     ...    ...         ...      ...       ...        ...      ...
# 1253   1255   GOOG  2021-06-07  2466.09  2468.000  2441.0725  2451.32
# 1254   1256   GOOG  2021-06-08  2482.85  2494.495  2468.2400  2479.90
# 1255   1257   GOOG  2021-06-09  2491.40  2505.000  2487.3300  2499.50
# 1256   1258   GOOG  2021-06-10  2521.60  2523.260  2494.0000  2494.01
# 1257   1259   GOOG  2021-06-11  2513.93  2526.990  2498.2900  2524.92
#
#        volume  adjClose   adjHigh     adjLow  adjOpen  adjVolume  divCash  \
# 0     1306065    718.27   722.470   713.1200   716.48    1306065      0.0
# 1     1214517    718.92   722.980   717.3100   719.00    1214517      0.0
# 2     1982471    710.36   716.650   703.2600   714.91    1982471      0.0
# 3     3402357    691.72   708.820   688.4515   708.65    3402357      0.0
# 4     2082538    693.71   702.480   693.4100   698.77    2082538      0.0
# ...       ...       ...       ...        ...      ...        ...      ...
# 1253  1192453   2466.09  2468.000  2441.0725  2451.32    1192453      0.0
# 1254  1253253   2482.85  2494.495  2468.2400  2479.90    1253253      0.0
# 1255  1006337   2491.40  2505.000  2487.3300  2499.50    1006337      0.0
# 1256  1561733   2521.60  2523.260  2494.0000  2494.01    1561733      0.0
# 1257  1262309   2513.93  2526.990  2498.2900  2524.92    1262309      0.0
#
#       splitFactor
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0
# ...           ...
# 1253          1.0
# 1254          1.0
# 1255          1.0
# 1256          1.0
# 1257          1.0
#
# [1258 rows x 15 columns]

# %%
dframe = dframe.set_index('date')
dframe

# %%
a= 5  # number of rows
b = 1  # number of columns
c = 1  # initialize plot counter
colors = plt.rcParams["axes.prop_cycle"]()
# A figure is initialized 
fig = plt.figure(figsize=(12,15))

for i in range(len(dframe.columns)):
    color = next(colors)["color"]
    plt.subplot(a, b, c)
    #Plotting the line for each column in a different color
    plt.plot(dframe[dframe.columns[i]], color = color)
    # The spines of each plot are made invisible and the figure is adjusted and shown.
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)
    #Adding a horizontal line for the average of the column
    plt.axhline(dframe[dframe.columns[i]].mean(), linestyle='--', lw=2, zorder=1, color='black')
    #Adding Title
    plt.title("Google "+ dframe.columns[i] + " figures", fontsize=16)
    plt.xlabel('Years')
    #Adding y axis label
    plt.ylabel(dframe.columns[i])
    #Adding Legend
    plt.legend([dframe.columns[i]])
    #Plot Counter value is increased by one after each iteration
    c = c + 1

#Layout is tightended up
plt.tight_layout()

#plot is displayed
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 10
#       8 for i in range(len(dframe.columns)):
#       9     color = next(colors)["color"]
# ---> 10     plt.subplot(a, b, c)
#      11     #Plotting the line for each column in a different color
#      12     plt.plot(dframe[dframe.columns[i]], color = color)
#
# File C:\Anaconda\Lib\site-packages\matplotlib\pyplot.py:1440, in subplot(*args, **kwargs)
#    1437 fig = gcf()
#    1439 # First, search for an existing subplot with a matching spec.
# -> 1440 key = SubplotSpec._from_subplot_args(fig, args)
#    1442 for ax in fig.axes:
#    1443     # If we found an Axes at the position, we can re-use it if the user passed no
#    1444     # kwargs or if the axes class and kwargs are identical.
#    1445     if (ax.get_subplotspec() == key
#    1446         and (kwargs == {}
#    1447              or (ax._projection_init
#    1448                  == fig._process_projection_requirements(**kwargs)))):
#
# File C:\Anaconda\Lib\site-packages\matplotlib\gridspec.py:599, in SubplotSpec._from_subplot_args(figure, args)
#     597 else:
#     598     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 599         raise ValueError(
#     600             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     601             f"not {num!r}"
#     602         )
#     603     i = j = num
#     604 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 5, not 6

# %%
plt.figure(figsize=(15, 6))
dframe['volume'].plot()
plt.ylabel('volume')
plt.xlabel(None)
plt.title("Sales Volume of google")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
dframe['close'].plot()
plt.ylabel('close')
plt.xlabel(None)
plt.title("close price")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
dframe['open'].plot()
plt.ylabel('open')
plt.xlabel(None)
plt.title("open price")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
dframe['open'].plot()
dframe['close'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title("Opening & Closing Price of google")
plt.legend(['Open Price', 'Close Price'])
plt.tight_layout()
plt.show()

# %%
# choose prediction column
pre = dframe["close"]
pre = pd.DataFrame(pre)

data = pre.values

data.shape
# Out:
# (1258, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0, 1))
scaled_data = scaler.fit_transform(np.array(data).reshape(-1, 1))

# %%
# 75% to Train , 25% to Test
train_size = int(len(data)*.75)
test_size = len(data) - train_size

print("Train Size :",train_size,"Test Size :",test_size)

train_data = scaled_data[ :train_size , 0:1 ]
test_data = scaled_data[ train_size-60: , 0:1 ]
# Out:
# Train Size : 943 Test Size : 315

# %%
# Creating a Training set with 60 time-steps and 1 output
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
# Convert to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)
# Reshaping the input
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_train.shape , y_train.shape
# Out:
# ((883, 60, 1), (883,))

# %%
model = Sequential([
    LSTM(50, return_sequences= True, input_shape= (x_train.shape[1], 1)),
    LSTM(64, return_sequences= False),
    Dense(32),
    Dense(16),
    Dense(1)
])

model.compile(optimizer= 'adam', loss= 'mse' , metrics= ["mean_absolute_error"])
# Out:
# C:\Anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
callbacks = [EarlyStopping(monitor= 'loss', patience= 10 , restore_best_weights= True)]
history = model.fit(x_train, y_train, epochs= 50, batch_size= 32 , callbacks= callbacks )
# Out:
# Epoch 1/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 0.0152 - mean_absolute_error: 0.0943
# Epoch 2/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 8.1595e-04 - mean_absolute_error: 0.0231
# Epoch 3/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.3015e-04 - mean_absolute_error: 0.0149
# Epoch 4/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.4464e-04 - mean_absolute_error: 0.0141
# Epoch 5/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.7594e-04 - mean_absolute_error: 0.0146
# Epoch 6/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.6502e-04 - mean_absolute_error: 0.0140
# Epoch 7/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.8408e-04 - mean_absolute_error: 0.0142
# Epoch 8/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.0985e-04 - mean_absolute_error: 0.0129
# Epoch 9/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.1044e-04 - mean_absolute_error: 0.0132
# Epoch 10/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.1132e-04 - mean_absolute_error: 0.0132
# Epoch 11/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.0629e-04 - mean_absolute_error: 0.0129
# Epoch 12/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.9581e-04 - mean_absolute_error: 0.0127
# Epoch 13/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.1888e-04 - mean_absolute_error: 0.0135
# Epoch 14/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.9155e-04 - mean_absolute_error: 0.0129
# Epoch 15/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.7954e-04 - mean_absolute_error: 0.0120
# Epoch 16/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.0544e-04 - mean_absolute_error: 0.0139
# Epoch 17/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.5435e-04 - mean_absolute_error: 0.0120
# Epoch 18/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.5947e-04 - mean_absolute_error: 0.0119
# Epoch 19/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.4423e-04 - mean_absolute_error: 0.0117
# Epoch 20/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.8135e-04 - mean_absolute_error: 0.0121
# Epoch 21/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.2001e-04 - mean_absolute_error: 0.0112
# Epoch 22/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.4096e-04 - mean_absolute_error: 0.0115
# Epoch 23/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.3151e-04 - mean_absolute_error: 0.0112
# Epoch 24/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.9396e-04 - mean_absolute_error: 0.0130
# Epoch 25/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.5485e-04 - mean_absolute_error: 0.0120
# Epoch 26/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.8370e-04 - mean_absolute_error: 0.0131
# Epoch 27/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.5264e-04 - mean_absolute_error: 0.0118
# Epoch 28/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.0420e-04 - mean_absolute_error: 0.0105
# Epoch 29/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.0831e-04 - mean_absolute_error: 0.0107
# Epoch 30/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.2223e-04 - mean_absolute_error: 0.0108
# Epoch 31/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.0486e-04 - mean_absolute_error: 0.0104
# Epoch 32/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.1436e-04 - mean_absolute_error: 0.0110
# Epoch 33/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.9021e-04 - mean_absolute_error: 0.0099
# Epoch 34/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.8282e-04 - mean_absolute_error: 0.0099
# Epoch 35/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.7956e-04 - mean_absolute_error: 0.0100
# Epoch 36/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.1054e-04 - mean_absolute_error: 0.0103
# Epoch 37/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.1419e-04 - mean_absolute_error: 0.0105
# Epoch 38/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.8323e-04 - mean_absolute_error: 0.0100
# Epoch 39/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.7543e-04 - mean_absolute_error: 0.0097
# Epoch 40/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.9173e-04 - mean_absolute_error: 0.0099
# Epoch 41/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.8121e-04 - mean_absolute_error: 0.0098
# Epoch 42/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.0240e-04 - mean_absolute_error: 0.0104
# Epoch 43/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.9561e-04 - mean_absolute_error: 0.0100
# Epoch 44/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.8123e-04 - mean_absolute_error: 0.0094
# Epoch 45/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.7648e-04 - mean_absolute_error: 0.0097
# Epoch 46/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.6059e-04 - mean_absolute_error: 0.0092
# Epoch 47/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.5177e-04 - mean_absolute_error: 0.0088
# Epoch 48/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.4239e-04 - mean_absolute_error: 0.0089
# Epoch 49/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.4057e-04 - mean_absolute_error: 0.0089
# Epoch 50/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.3225e-04 - mean_absolute_error: 0.0083

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["mean_absolute_error"])
plt.legend(['loss','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %%
# Creating a testing set with 60 time-steps and 1 output
x_test = []
y_test = []

for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    y_test.append(test_data[i, 0])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
x_test.shape , y_test.shape
# Out:
# ((315, 60, 1), (315,))

# %%
#inverse y_test scaling
predictions = model.predict(x_test)

#inverse predictions scaling
predictions = scaler.inverse_transform(predictions)
predictions.shape
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step
# (315, 1)

# %%
#inverse y_test scaling
y_test = scaler.inverse_transform([y_test])

RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# 40.15

# %%
train = pre.iloc[:train_size , 0:1]
test = pre.iloc[train_size: , 0:1]
test['Predictions'] = predictions

plt.figure(figsize= (16, 6))
plt.title('google Close Stock Price Prediction', fontsize= 18)
plt.xlabel('Date', fontsize= 18)
plt.ylabel('Close Price', fontsize= 18)
plt.plot(train['close'], linewidth= 3)
plt.plot(test['close'], linewidth= 3)
plt.plot(test["Predictions"], linewidth= 3)
plt.legend(['Train', 'Test', 'Predictions'])
